# %%
n = int(input())
i = 1
while i<= n:
    j = 1
    while j <= n-i+1:
        print(j,end="")
        j+=1
    spaces = 1    
    while spaces <= i-1:
        print('**',end='')
        spaces+=1
    j = n-i+1
    while j>=1:
        print(j,end="")
        j-=1
    print()
    i+=1
# Out:
# 4
# 12344321
# 123**321
# 12****21
# 1******1

# %%
n = 4
i = 1
while i <= n:
    spaces = i
    while spaces <= n-1:
        print(' ',end="")
        spaces+=1
    j = 1
    while j <= i:
        print('*',end ="")
        j+=1
    print()
    i+=1
# Out:
#    *
#   **
#  ***
# ****

# %%
def birthdayCakeCandles(candles):
    # Write your code here
    l = len(candles)
    count = 0
    for i in range(l):
        for k in range(i+1,l):
            if candles[i] == candles[k]:
                count+=2
    return count
            
            
candels = [1,2,3,4,3]
birthdayCakeCandles(candels)
# Out:
# 2

# %%
#!/bin/python3

import math
import os
import random
import re
import sys
import datetime

#
# Complete the 'timeConversion' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#

def timeConversion(s):
    # Write your code here
    if s[-2:] == 'PM' and s[:2] == '12':
        return s[:-2]
    
    elif s[-2] == 'AM' and s[:2] == '12':
        return '00' + s[2:-2]
    
    elif s[:2] == '12':
        return '00' + s[2:-2]
        
        
    elif s[-2:] == 'AM':
        return s[:-2]
    
    
    
    else:
        return str(int(s[:2])+ 12) + s[2:8]
    
s = "12:45:54PM"
a= "12:40:22AM"
print(timeConversion(s))
timeConversion(a)
# Out:
# 12:45:54
# '00:40:22'

# %%
true = True
false = False
n = [true,false,true,false,false,true,true,true,true]
bol = list(map(int,n))
print(bol)
l = len(n)
minn = 0
maxx = 0
for i in range(l):
    if bol[i] == 0:
        minn+=0
    elif bol[i] == 1:
        maxx += 1
print([minn,maxx])
# Out:
# [1, 0, 1, 0, 0, 1, 1, 1, 1]
# [0, 6]

# %%
n = int(input())
arr = list((input().split())

for i in range(n):
    arr[i] = int(arr[i])

arr.sort()
print(arr[0])
# Out:
#   File "<ipython-input-3-34755df1da2c>", line 4
#     for i in range(n):
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# Reverse sentence and swap letter

# %%
a = "cODING iS life"
def reverse(a):
    word = a.split()
    reverse = word[::-1]
    reverse_sen = ' '.join(reverse)
    return reverse_sen.swapcase()

print(reverse(a))
# Out:
# LIFE Is Coding

# %% [markdown]
# Create sentence using OOP

# %%
class Car:
    def __init__(self,speed,unit):
        self.speed = speed
        self.unit = unit
        
    def __str__(self):
        str1 = "This car is running with the maximum speed of {} {} "
        return str1.format(self.speed,self.unit)
    
    
class Boat:
    def __init__(self,speed):
        self.speed = speed
        
    def __str__(self):
        str2 = "The Boat have the maximum speed of {} knots"
        return str2.format(self.speed)

speed = 100
unit = "km/h"
a = Car(speed,unit)
print(a)

b = Boat(70)
print(b)
# Out:
# This car is running with the maximum speed of 100 km/h
# The Boat have the maximum speed of 70 knots

# %% [markdown]
# Addition

# %%
def add(param1, param2):
    sum = param1 + param2
    return sum

add(2,5)
# Out:
# 7

# %% [markdown]
# CenturyFromYear(year)

# %%
def CenturyFY(year):
    ans = (year-1)//100
    return ans+1

CenturyFY(1700)
# Out:
# 17

# %% [markdown]
# Check Palindrome

# %%
def Palindrome(string):
    return string == string[::-1]

string = input()

if Palindrome:
    print('True')
else:
    print('False')
# Out:
# aba
# True

# %% [markdown]
# Given an array of integers, find the pair of adjacent elements that has the largest product and return that product.

# %%
def adjcElePr(arr):
    return max(a*b for a,b in zip(arr,arr[1:]))

arr = [int(ele) for ele in input().split()]
adjcElePr(arr)
# Out:
# 3 6 -2 -5 7 3
# 21

# %% [markdown]
# ShapeArea

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def shapeArea(n):
    if n == 1:
        return 1
    else:
        a = 1
        for i in range(1,n+1):
            a = a+i*4-4
        return a
    
n = int(input())
shapeArea(n)
# Out:
# 3
# 13

# %% [markdown]
# Uber coding challenge

# %%
def perfectCity(departure, destination):
    import math
    (depX, depY) = departure
    (desX,desY) = destination
    distances = []
    
    for i in [math.floor,math.ceil]:
        x = depX
        y = depY
        distance = 0
        while 1:
            dx,dy = 0,0
            if x == desX:
                dy = desY-y
            elif y == desY:
                dx = desX-x
            elif x % 1 != 0:
                dx = i(x) - depX
            elif y % 1 != 0:
                dy = i(y) - depY
            elif desX % 1 != 0:
                dy = desY - y
            elif desY % 1 != 0:
                dx = desX-x
                
            distance += abs(dx+dy)
            x+=dx
            y+=dy
            
            if x == desX and y == desY:
                break
    
        distances.append(distance)
        
    return min(distances)

# %%
from sys import stdin

def longestConsecutiveSubsequence(arr,n): 
    visitedElements = {}
    elementToIndexMapping = {}
    for i in range(n):
        elementToIndexMapping[arr[i]] = i
        if arr[i] not in visitedElements:
            visitedElements[arr[i]]=True
            
    longestSequence=[]
    maxSequenceLength = 1
    minStartIndex = 0
    
    for i in range(n):
        num = arr[i]
        currentMinStartIndex = i
        count = 0
        tempNum = num
        
        while tempNum in visitedElements and visitedElements[tempNum]==True:
            visitedElements[tempNum] = False
            count+=1
            tempNum+=1
        
        tempNum = num - 1
        while tempNum in visitedElements and visitedElements[tempNum]==True:
            visitedElements[tempNum] = False
            count+=1
            currentMinStartIndex = elementToIndexMapping[tempNum]
            tempNum-=1
            
        if (count > maxSequenceLength):
            maxSequenceLength = count
            minStartIndex = currentMinStartIndex
        elif (count == maxSequenceLength):
            if (currentMinStartIndex < minStartIndex):
                minStartIndex = currentMinStartIndex
                
    startNum = arr[minStartIndex]

    longestSequence.append(startNum)
    if (maxSequenceLength > 1):
        longestSequence.append(startNum + maxSequenceLength - 1)
    
    
    return longestSequence
            
        


def takeInput():
    #To take fast I/O
    n=int(stdin.readline().strip())
    if n==0:
        return list(),0
    arr=list(map(int,stdin.readline().strip().split( )))
    return arr,n

    
# Main 
arr,n=takeInput()
ans = longestConsecutiveSubsequence(arr,n) 
# This ans array contains two numbers, ie, start and end of longest sequence respectively
print(*ans)

# %% [markdown]
# Base 2 to 6

# %%
def bin_to_hex(arr):
    decimal = 0
    for i in range(len(arr)):
        decimal += int(arr[i]) * (2**i)
    print(decimal)

    hex = []
    while decimal>0:
        hex.append(decimal%6)
        decimal//=6
    return hex

arr = [False,True,True,True,True]
bin_to_hex(arr)
# Out:
# 30
# [0, 5]

# %%
a = [-1,20,98,23,5,-1,4]
s = sorted(x for x in a if x != -1)
print(s)
# Out:
# [4, 5, 20, 23, 98]

# %%
def addBorder(picture):
    m = len(picture)
    n = len(picture[0])
    
    new = ['*'*(n+2) for y in range(m+2)]
    
    for item, text in enumerate(picture):
        new[item+1] = '*' + text + '*'
    return new


picture=["abc","ded"]

addBorder(picture)
# Out:
# ['*****', '*abc*', '*ded*', '*****']
