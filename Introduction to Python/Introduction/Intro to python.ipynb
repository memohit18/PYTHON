# %% [markdown]
# ## Variables

# %% [markdown]
# using 3 storage here a and b is storing 10 and 20 and sum is storing the the addition of a and b

# %% [markdown]
# varibles name cannot be started with number

# %%
a = 10
b = 20
sum = a+b
print(sum)
# Out:
# 30

# %% [markdown]
# ## Assigning different type of data to a variable

# %% [markdown]
# in python variable store the address only

# %%
a = 10
a = 20
a = "mohit"
a
# Out:
# 'mohit'

# %%
type(a)
# Out:
# str

# %%
b = 10

# %%
type(b)
# Out:
# int

# %% [markdown]
# ## Python Numbers

# %%
a1 = 23
a2 = 3.4
a3 = 4+5j
print(type(a1))
print(type(a2))
print(type(a3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# Id method is used to get the unique id for a variable where it is refering to

# %%
a = 10
print(id(a))
a = a+1
print(id(a))
# Out:
# 140710544025680
# 140710544025712

# %% [markdown]
# here below both a and b are refering to same storage but python do this only from -5 to 256 more than that the id will change

# %%
a = 10
b = 10
print(id(a))
print(id(b))
# Out:
# 140710544025680
# 140710544025680

# %% [markdown]
# ## Limit of Integers

# %% [markdown]
#  Don't have any limit to size of data

# %% [markdown]
# ## Arithmatic Operators

# %%
a = 10
b = 4
print(a-b)
print(a+b)
print(a*b)
print(a/b) #floating division
print(a//b)#integer division
print(a**b) #exponentiation
print(a%b) #modules
# Out:
# 6
# 14
# 40
# 2.5
# 2
# 10000
# 2

# %%
#simple interest to lower integer
p = 100
r = 12
t = 2
si = (p*r*t)// 100
si
# Out:
# 24

# %%
#fah to celcium conversion
f = 100
c  = (f-32)* 5/9
print(c)
ci = (f-32)*5//9
print(ci)
# Out:
# 37.77777777777778
# 37

# %% [markdown]
# Taking Input

# %%
a = input() #always take input as string
print(type(a))
b = int(input()) # to convert string into intger we use int
print(type(b))
# Out:
# 23
# <class 'str'>
# 23
# <class 'int'>

# %%
a = int(input())
b = int(input())
sum = a + b
print(sum)
# Out:
# 23
# 34
# 57

# %% [markdown]
# #find avg marks

# %%
a = int(input())
b = int(input())
c = int(input())
avg = (a+b+c)/c
print(avg)
# Out:
# 3
# 4
# 6
# 2.1666666666666665

# %% [markdown]
# Find X raised to power N

# %%
n = int(input())
e = int(input())
total = n**e
print(total)
# Out:
# 10
# 4
# 10000

# %% [markdown]
# Arithmetic Progression

# %%
a = int(input())
b = int(input())
c = int(input())
diff = b-a
print(diff)
# Out:
# 1
# 3
# 5
# 2

# %% [markdown]
# Rectangular Area

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
rectangle = (c-a)*(d-b)
print(rectangle)
# Out:
# 1
# 3
# 2
# 4
# 1
